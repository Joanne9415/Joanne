# %% [markdown]
# <a href="https://colab.research.google.com/github/Joanne9415/Joanne/blob/main/%E7%A8%8B%E5%BC%8F%E4%BD%9C%E6%A5%AD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""程式作業1

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1RCXzKpOUbCVVOjVAkaslBzs1IuLlLH1X
"""

INF = 10**9   # 用來取代輸入中的 -1（代表 ∞）

# 讀取 n
n = int(input().strip())

# 讀取相鄰矩陣
W = []
for _ in range(n):
    row = list(map(int, input().split()))
    # 將 -1（代表 ∞）改成 INF；對角線為 0
    for i in range(n):
        if row[i] == -1 and i != len(W):
            row[i] = INF
    W.append(row)

# Floyd-Warshall
D = [row[:] for row in W]

for k in range(n):
    for i in range(n):
        for j in range(n):
            if D[i][k] + D[k][j] < D[i][j]:
                D[i][j] = D[i][k] + D[k][j]

# 輸出格式（以一個空白隔開）
for i in range(n):
    for j in range(n):
        print(D[i][j], end=" " if j < n-1 else "")
    print()
# Out:
# 5
#  0   1  -1   1   5
#  9   0   3   2  -1
# -1  -1   0   4  -1
# -1  -1   2   0   3
#  3  -1  -1  -1   0
# 0 1 3 1 4
# 8 0 3 2 5
# 10 11 0 4 7
# 6 7 2 0 3
# 3 4 6 4 0
